# %%
import itertools

from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn

# %% [markdown]
# # Question 1
# ## (a)

# %%
import pickle
from torch.utils.data import Dataset, DataLoader


class MnistDataset():
    def __init__(self, X, y, transform_X=lambda x: x):
        assert X.shape[0] == y.shape[0]
        self.X = transform_X(X)
        self.y = y
    
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

    
def load_mnist(path):
    with open(path, 'rb') as f:
        train_data, test_data = pickle.load(f)
    
    X_train = torch.tensor(train_data[0], dtype=torch.float).unsqueeze(1)
    y_train = torch.tensor(train_data[1], dtype=torch.long)
    X_test = torch.tensor(test_data[0], dtype=torch.float).unsqueeze(1)
    y_test = torch.tensor(test_data[1], dtype=torch.long)
    return X_train, y_train, X_test, y_test

# %%
# load data and normalize by dividing the maximum value
X_train, y_train, X_test, y_test = load_mnist("mnist.pkl")
X_train = X_train / torch.max(X_train)
X_test = X_test / torch.max(X_test)

# %%
# further split the train to train/validation with 80/20 
train_index, val_index = train_test_split(np.arange(len(X_train)), test_size=0.2)

# use MnistDataset class to handle the data
train_data = MnistDataset(X_train[train_index], y_train[train_index])
val_data = MnistDataset(X_train[val_index], y_train[val_index])
test_data = MnistDataset(X_test, y_test)

# %% [markdown]
# ## (b)

# %%
class VAE(nn.Module):
    def __init__(self, in_channels=1, z_dim=32):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 4, kernel_size=4, padding=1, stride=2), # conv1, input_channel -> 4
            nn.ReLU(), # relu
            nn.Conv2d(4, 8, kernel_size=4, padding=1, stride=2), # conv2, channel 4 -> 8
            nn.ReLU(), # relu
            nn.Conv2d(8, 16, kernel_size=4, padding=1, stride=2), # conv3, channel 8 -> 16
            nn.ReLU(), # relu
            nn.Conv2d(16, 32, kernel_size=4, padding=1, stride=2), # conv4, channel 16 -> 32
            nn.ReLU(), # relu
            nn.Flatten(), # flatten
        )
        
        # manually calculate the dimension after all convolutions
        dim_after_conv = 2
        hidden_dim = 32 * dim_after_conv * dim_after_conv
        
        self.readout_mu = nn.Linear(hidden_dim, z_dim)
        self.readout_sigma = nn.Linear(hidden_dim, z_dim)
        
        # You can use nn.ConvTranspose2d to decode
        self.decoder = nn.Sequential(
            nn.Linear(z_dim, hidden_dim),
            nn.Unflatten(1, (32, dim_after_conv, dim_after_conv)),
            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1), # transpose-conv, channel 32 -> 16
            nn.ReLU(), # relu
            nn.ConvTranspose2d(16, 8, kernel_size=4, stride=2, padding=1), # transpose-conv, channel 16 -> 8
            nn.ReLU(), # relu
            nn.ConvTranspose2d(8, 4, kernel_size=4, stride=2, padding=1), # transpose-conv, channel 8 -> 4
            nn.ReLU(), # relu
            nn.ConvTranspose2d(4, in_channels, kernel_size=4, stride=2, padding=1), # transpose-conv, channel 4 -> input_channel, which is 1
            nn.Sigmoid(), # use a sigmoid activation to squeeze the outputs between 0 and 1
        )
    
    def reparameterize(self, mu, sigma):
        """
        Reparameterize, i.e. generate a z ~ N(\mu, \sigma)
        """
        # generate epsilon ~ N(0, I)
        # hint: use torch.randn or torch.randn_like
        epsilon = torch.rand_like(sigma)
        # z = \mu + \sigma * \epsilon
        z = mu + sigma * epsilon
        return z

    def encode(self, x):
        # call the encoder to map input to a hidden state vector
        h = self.encoder(x)
        # use the "readout" layer to get \mu and \sigma
        mu = self.readout_mu(h)
        sigma = self.readout_sigma(h)
        return mu, sigma

    def decode(self, z):
        # call the decoder to map z back to x
        return self.decoder(z)

    def forward(self, x):
        mu, sigma = self.encode(x)
        z = self.reparameterize(mu, sigma)
        x_recon = self.decode(z)
        return x_recon, mu, sigma

# %% [markdown]
# ## (c)
#
# *For debugging*: The `test_kld_loss_func` should output 1.3863

# %%
def kld_loss_func(mu, sigma):
    """
    KL-Divergence: KLD = 0.5 * sum(\mu^2 + \sigma^2 - ln(\sigma^2) - 1)
    
    Parameters
    ----------
    mu: torch.Tensor
        Mean vector in the VAE bottleneck region
    sigma: torch.Tensor
        Standard Deviation vector in the VAE bottleneck region
    
    Return
    ------
    kld: torch.Tensor
        KL-Divegence loss (a scalar)
    """
    kld = 0.5 * torch.sum(mu**2 + sigma**2 - torch.log(sigma**2) - 1)
    return kld


def vae_loss_func(recon_x, x, mu, sigma):

    bce_loss = nn.BCELoss(reduction='sum')(recon_x, x)
    kld_loss = kld_loss_func(mu, sigma)

    return bce_loss + kld_loss


def test_kld_loss_func():
    mu = torch.tensor([0.5, 0.5, 1.0])
    sigma = torch.tensor([1.0, 0.5, 0.5])
    print(kld_loss_func(mu, sigma))

test_kld_loss_func()
# Out:
# tensor(1.3863)

# %%
import torch.nn.functional as F

class VAETrainer:
    
    def __init__(self, model, learning_rate, batch_size, epoch, l2):
        self.model = model
        num_params = sum(item.numel() for item in model.parameters())
        print(f"{model.__class__.__name__} - Number of parameters: {num_params}")
        
        self.optimizer = torch.optim.Adam(model.parameters(), learning_rate, weight_decay=l2)
        
        self.epoch = epoch
        self.batch_size = batch_size
        

    
    def train(self, train_data, val_data, early_stop=True, verbose=True, draw_curve=True):
        train_loader = DataLoader(train_data, batch_size=self.batch_size, shuffle=True)
        
        train_loss_list = []
        val_loss_list = []
        
        weights = self.model.state_dict()
        lowest_val_loss = np.inf

        for n in tqdm(range(self.epoch), leave=False):
            self.model.train()
            epoch_loss = 0.0
            for X_batch, y_batch in train_loader:
                batch_importance = 1 / len(train_data)
                # call the model
                X_batch_recon, mu, sigma = self.model(X_batch)
                batch_loss = vae_loss_func(X_batch_recon, X_batch, mu, sigma)

                self.optimizer.zero_grad()
                batch_loss.backward()
                self.optimizer.step()
                
                epoch_loss += batch_loss.detach().cpu().item() * batch_importance
            
            train_loss_list.append(epoch_loss)
            
            val_loss = self.evaluate(val_data, print_loss=False)
            val_loss_list.append(val_loss)
            
            if early_stop:
                if val_loss < lowest_val_loss:
                    lowest_val_loss = val_loss
                    weights = self.model.state_dict()
            
        if draw_curve:
            x_axis = np.arange(self.epoch)
            fig, ax = plt.subplots(1, 1, figsize=(5, 4))
            ax.plot(x_axis, train_loss_list, label="Train")
            ax.plot(x_axis, val_loss_list, label="Validation")
            ax.set_title("Total Loss")
            ax.set_xlabel("# Epoch")
        
        if early_stop:
            self.model.load_state_dict(weights)
        
        return {
            "train_loss_list": train_loss_list,
            "val_loss_list": val_loss_list,
        }
    
    def evaluate(self, data, print_loss=True):
        self.model.eval()
        loader = DataLoader(data, batch_size=self.batch_size)
        total_loss = 0.0
        for X_batch, y_batch in loader:
            with torch.no_grad():
                batch_importance = 1 / len(data)
                X_batch_recon, mu, sigma = self.model(X_batch)
                batch_loss = vae_loss_func(X_batch_recon, X_batch, mu, sigma)
                total_loss += batch_loss.detach().cpu().item() * batch_importance
        if print_loss:
            print(f"Total Loss: {total_loss}")
        return total_loss

# %%
vae = VAE()
trainer = VAETrainer(vae, learning_rate=1e-3, batch_size = 512, epoch = 30, l2 = 1e-5)
# train
trainer.train(train_data, val_data)
# Out:
# VAE - Number of parameters: 34201
# {'train_loss_list': [507.6393287760414,
#   216.36293457031243,
#   204.65435839843744,
#   200.50741373697917,
#   195.88631901041663,
#   183.59592578124995,
#   170.38416113281244,
#   163.80734757486985,
#   157.6070879720052,
#   152.0776225585938,
#   146.77445133463544,
#   142.4870455729167,
#   138.6179116210937,
#   133.63231127929689,
#   129.17662792968753,
#   125.19348665364582,
#   121.60064819335936,
#   118.86527449544269,
#   116.2995131022135,
#   113.96570621744789,
#   112.11468074544271,
#   110.52652596028645,
#   109.0782705891927,
#   107.97187719726558,
#   106.80218823242188,
#   105.88457706705724,
#   104.90570035807295,
#   103.95324983723958,
#   103.10550528971358,
#   102.42383536783852],
#  'val_loss_list': [237.29805208333332,
#   208.19192610677086,
#   202.13478059895832,
#   199.02098307291664,
#   192.43872623697914,
#   175.51831705729165,
#   166.64960319010413,
#   160.46567187499997,
#   154.8917034505208,
#   149.4310498046875,
#   144.46958691406252,
#   140.6409435221354,
#   136.4384718424479,
#   131.36864453125,
#   127.30314371744791,
#   123.30083528645834,
#   120.29013525390626,
#   117.57625455729166,
#   114.82501139322918,
#   113.16358203124999,
#   111.16244108072915,
#   110.0535128580729,
#   108.36538167317708,
#   107.58371175130208,
#   106.40284863281249,
#   105.50144547526041,
#   104.69592952473958,
#   103.42683186848956,
#   102.57051529947917,
#   102.25075260416664]}

# %%
# evaulate the qualitiy of reconstruction
def plot_digits(data, title):
    fig, axes = plt.subplots(5, 5, figsize=(6, 6))
    fig.subplots_adjust(hspace=0.1, wspace=0.1)
    fig.suptitle(title)
    for i, ax in enumerate(axes.flatten()):
        im = ax.imshow(data[i].reshape(32, 32), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])

def compare_reconstruct(model, X):
    plot_digits(X, "Original Data")
    with torch.no_grad():
        X_recon, _, _ = model(X)
    plot_digits(X_recon, "Reconstructed Data")


compare_reconstruct(trainer.model, X_test[:100])

# %% [markdown]
# # Question 2

# %%
from torch_geometric.datasets import QM9
from torch_geometric.loader import DataLoader as GraphDataLoader
from torch_geometric.utils import scatter

# %% [markdown]
# ## (a)

# %%
def load_qm9(path="./QM9"):
    def transform(data):
        edge_index = torch.tensor(
            list(itertools.permutations(range(data.x.shape[0]), 2)), 
            dtype=torch.long
        ).T
        edge_feature = 1 / torch.sqrt(
            torch.sum(
                (data.pos[edge_index[0]] - data.pos[edge_index[1]]) ** 2, 
                axis=1, keepdim=True
            )
        )
        data.edge_index = edge_index
        data.edge_attr = edge_feature
        data.y = data.y[:, [-7]]
        return data
    
    qm9 = QM9(path, transform=transform)
    return qm9

qm9 = load_qm9("Datasets/QM9")
train_index, test_index = train_test_split(np.arange(len(qm9)), test_size=0.2,) # use train_test_split to do the index
train_data = qm9[train_index]
test_data = qm9[test_index]

# %%
# find out the dimension of node input features
node_input_dim = 11
edge_input_dim = 1

# %% [markdown]
# ## (b)

# %%
class Layer(nn.Module):
    """
    Basic layer, a linear layer with a ReLU activation 
    """
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(in_dim, out_dim), # linear layer
            nn.ReLU() # relu
        )
    
    def forward(self, x):
        return self.layers(x)
    
    
class MessagePassingLayer(nn.Module):
    """
    A message passing layer that updates nodes/edge features
    """
    def __init__(self, node_hidden_dim, edge_hidden_dim):
        super().__init__()
        self.edge_net = Layer(node_hidden_dim * 2 + edge_hidden_dim, edge_hidden_dim)
        self.node_net = Layer(edge_hidden_dim + node_hidden_dim, node_hidden_dim)
    
    def forward(self, node_features, edge_features, edge_index):
        """
        Update node and edge features
        
        Parameters
        ----------
        node_features: torch.Tensor
            Node features from the previous layer
        edge_features: torch.Tensor
            Edge features from the previous layer
        edge_index: torch.Tensor
            A sparse matrix (n_edge, 2) in which each column denotes node indices forming an edge
        """
        # concatnate previous edge features with node features forming the edge
        # hint: use node_features[edge_index[0(or 1)]] to get node features forming the edge
        concate_edge_features = torch.cat([
            node_features[edge_index[0]], # features of one node
            node_features[edge_index[1]], # features of the other node
            edge_features # previous edge features
        ], dim=1)
        
        # pass through the "edge_net" to map it back to the original dimension
        updated_edge_features = self.edge_net(concate_edge_features)
        
        
        # use scatter to aggrate the edge features to nodes
        aggr_edge_features = scatter(updated_edge_features, edge_index[0])
        # concatenate it with previous node features
        concate_node_features = torch.cat([aggr_edge_features, node_features], dim=1)
        # pass through the "node_net" to map it back to the original dimension
        updated_node_features = self.node_net(concate_node_features)
        
        return updated_node_features, updated_edge_features

        
class GraphNet(nn.Module):
    def __init__(self, node_input_dim, edge_input_dim, node_hidden_dim, edge_hidden_dim):
        super().__init__()
        # embed the input node features
        self.node_embed = Layer(node_input_dim, node_hidden_dim)
        # embed the input edge features
        self.edge_embed = Layer(edge_input_dim, edge_hidden_dim)
        # readout layer to get the "atomic" energy contribution
        self.readout = nn.Linear(node_hidden_dim, 1)
        # message passing layer
        self.message_passing = MessagePassingLayer(node_hidden_dim, edge_hidden_dim)
    
    def forward(self, node_features, edge_features, edge_index, batch):
        """
        Update node and edge features
        
        Parameters
        ----------
        node_features: torch.Tensor
            Node features from the previous layer
        edge_features: torch.Tensor
            Edge features from the previous layer
        edge_index: torch.Tensor
            A sparse matrix (n_edges, 2) in which each column denotes node indices forming an edge
        batch: torch.Tensor
            A 1-D tensor (n_nodes,) that tells you each node belongs to which graph
        """
        node_hidden = self.node_embed(node_features) # call the node embedding
        edge_hidden = self.edge_embed(edge_features) # call the edge embedding
        updated_node_hidden, updated_edge_hidden = self.message_passing(node_hidden, edge_hidden, edge_index)
        readout = self.readout(updated_node_hidden) # use the readout layer to output "atomic" contributions
        out = scatter(readout, batch, dim=0) # use the scatter function to aggregate atomic readouts
        return out

# %%
class GNNTrainer:
    def __init__(self, model, batch_size, learning_rate, epoch, l2):
        self.model = model
        
        num_params = sum(item.numel() for item in model.parameters())
        print(f"{model.__class__.__name__} - Number of parameters: {num_params}")
        
        self.batch_size = batch_size
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=learning_rate, weight_decay=l2)
        self.epoch = epoch
    
    def train(self, dataset, draw_curve=True):
        self.model.train()
        loader = GraphDataLoader(dataset, batch_size=self.batch_size, shuffle=True)
        
        loss_func = nn.MSELoss()
        batch_loss_list = []
        for i in range(self.epoch):
            print(f"Epoch: {i}")
            for batch_data in tqdm(loader, leave=False):
                batch_size = batch_data.y.shape[0]
                batch_pred = self.model(
                    batch_data.x, batch_data.edge_attr, 
                    batch_data.edge_index, batch_data.batch
                )
                batch_loss = loss_func(batch_data.y, batch_pred)

                self.optimizer.zero_grad()
                batch_loss.backward()
                self.optimizer.step()

                batch_loss_list.append(batch_loss.detach().numpy())
        
        if draw_curve:
            fig, ax = plt.subplots(1, 1, figsize=(5, 4), constrained_layout=True)
            ax.set_yscale("log")
            ax.plot(np.arange(len(batch_loss_list)), batch_loss_list)
            ax.set_xlabel("# Batch")
            ax.set_ylabel("Loss")
        
        return batch_loss_list
    
    def evaluate(self, dataset, draw_curve=True):
        self.model.eval()
        loader = GraphDataLoader(dataset, batch_size=self.batch_size)
        y_true, y_pred = [], []
        with torch.no_grad():
            for batch_data in tqdm(loader, leave=False):
                batch_pred = self.model(
                    batch_data.x, 
                    batch_data.edge_attr, 
                    batch_data.edge_index, 
                    batch_data.batch
                )
                y_pred.append(batch_pred.detach().numpy().flatten())
                y_true.append(batch_data.y.detach().numpy().flatten())
        
        y_true = np.concatenate(y_true)
        y_pred = np.concatenate(y_pred)
        mse = np.mean((y_true - y_pred) ** 2)
        
        if draw_curve:
            fig, ax = plt.subplots(1, 1, figsize=(5, 4), constrained_layout=True)
            ax.scatter(y_true, y_pred, label=f"MSE: {mse:.2f}", s=2)
            ax.set_xlabel("Ground Truth")
            ax.set_ylabel("Predicted")
            xmin, xmax = ax.get_xlim()
            ymin, ymax = ax.get_ylim()
            vmin, vmax = min(xmin, ymin), max(xmax, ymax)
            ax.set_xlim(vmin, vmax)
            ax.set_ylim(vmin, vmax)
            ax.plot([vmin, vmax], [vmin, vmax], color='red')
            ax.legend()
            
        return mse

# %% [markdown]
# ## (c)

# %%
node_hidden_dim = 64
edge_hidden_dim = 64

net = GraphNet(node_input_dim, edge_input_dim, node_hidden_dim, edge_hidden_dim)

# %%
# train
learning_rate = 1e-3
n_epoch = 30
batch_size = 512

trainer = GNNTrainer(model=net, batch_size=batch_size, learning_rate=learning_rate, epoch=n_epoch, l2=1e-5)
trainer.train(train_data, val_data)
# Out:
# GraphNet - Number of parameters: 21569
# Epoch: 0
# Epoch: 1
# Epoch: 2
# Epoch: 3
# Epoch: 4
# Epoch: 5
# Epoch: 6
# Epoch: 7
# Epoch: 8
# Epoch: 9
# Epoch: 10
# Epoch: 11
# Epoch: 12
# Epoch: 13
# Epoch: 14
# Epoch: 15
# Epoch: 16
# Epoch: 17
# Epoch: 18
# Epoch: 19
# Epoch: 20
# Epoch: 21
# Epoch: 22
# Epoch: 23
# Epoch: 24
# Epoch: 25
# Epoch: 26
# Epoch: 27
# Epoch: 28
# Epoch: 29
# [array(5847.6084, dtype=float32),
#  array(3392.706, dtype=float32),
#  array(1567.55, dtype=float32),
#  array(463.08203, dtype=float32),
#  array(87.71146, dtype=float32),
#  array(377.00342, dtype=float32),
#  array(788.2539, dtype=float32),
#  array(881.2231, dtype=float32),
#  array(729.05536, dtype=float32),
#  array(427.48108, dtype=float32),
#  array(151.29134, dtype=float32),
#  array(85.26817, dtype=float32),
#  array(119.14775, dtype=float32),
#  array(193.59795, dtype=float32),
#  array(253.51674, dtype=float32),
#  array(313.40414, dtype=float32),
#  array(291.10715, dtype=float32),
#  array(249.01634, dtype=float32),
#  array(205.33388, dtype=float32),
#  array(130.33914, dtype=float32),
#  array(92.78188, dtype=float32),
#  array(83.80413, dtype=float32),
#  array(80.42935, dtype=float32),
#  array(128.56111, dtype=float32),
#  array(133.35645, dtype=float32),
#  array(142.64362, dtype=float32),
#  array(154.74478, dtype=float32),
#  array(114.02597, dtype=float32),
#  array(114.29693, dtype=float32),
#  array(88.27765, dtype=float32),
#  array(67.98095, dtype=float32),
#  array(77.62338, dtype=float32),
#  array(79.19414, dtype=float32),
#  array(3.0859814, dtype=float32),
#  array(2.9471326, dtype=float32),
#  array(3.0226793, dtype=float32),
#  array(2.7290673, dtype=float32),
#  array(3.3238974, dtype=float32),
#  array(3.39828, dtype=float32),
#  array(3.7933927, dtype=float32),
#  array(3.299335, dtype=float32),
#  array(2.953862, dtype=float32),
#  array(3.4309068, dtype=float32),
#  array(2.9432132, dtype=float32),
#  array(2.8069937, dtype=float32),
#  array(3.2906766, dtype=float32),
#  array(3.1537397, dtype=float32),
#  array(3.060097, dtype=float32),
#  array(3.3278613, dtype=float32),
#  array(3.856713, dtype=float32),
#  array(2.9428117, dtype=float32),
#  array(3.0859659, dtype=float32),
#  array(2.9797845, dtype=float32),
#  array(2.99433, dtype=float32),
#  array(3.4751582, dtype=float32),
#  array(3.095451, dtype=float32),
#  array(2.8923597, dtype=float32),
#  array(3.3849533, dtype=float32),
#  array(2.9609318, dtype=float32),
#  array(2.8478668, dtype=float32),
#  array(2.984639, dtype=float32),
#  array(2.4854527, dtype=float32),
#  array(2.9543457, dtype=float32),
#  array(2.5952294, dtype=float32),
#  array(2.8516212, dtype=float32),
#  array(2.9390097, dtype=float32),
#  array(3.032233, dtype=float32),
#  array(2.6576438, dtype=float32),
#  array(2.307, dtype=float32),
#  array(2.683844, dtype=float32),
#  array(2.9531841, dtype=float32),
#  array(2.3141234, dtype=float32),
#  array(3.4199014, dtype=float32),
#  array(2.679513, dtype=float32),
#  array(2.622756, dtype=float32),
#  array(3.3271239, dtype=float32),
#  array(2.887292, dtype=float32),
#  array(4.1944313, dtype=float32),
#  array(3.489126, dtype=float32),
#  array(2.9800494, dtype=float32),
#  array(3.1154633, dtype=float32),
#  array(2.3572881, dtype=float32),
#  array(2.823188, dtype=float32),
#  array(2.7728531, dtype=float32),
#  array(2.5232918, dtype=float32),
#  array(2.7564294, dtype=float32),
#  array(2.7320857, dtype=float32),
#  array(2.4426084, dtype=float32),
#  array(2.8099306, dtype=float32),
#  array(2.6952486, dtype=float32),
#  array(2.800814, dtype=float32),
#  array(2.4082296, dtype=float32),
#  array(2.4433033, dtype=float32),
#  array(2.918263, dtype=float32),
#  array(2.778958, dtype=float32),
#  array(2.5747643, dtype=float32),
#  array(3.2044985, dtype=float32),
#  array(2.533774, dtype=float32),
#  array(2.717382, dtype=float32),
#  array(2.6648586, dtype=float32),
#  array(2.5991943, dtype=float32),
#  array(2.5765607, dtype=float32),
#  array(3.0696645, dtype=float32),
#  array(2.344587, dtype=float32),
#  array(2.6197042, dtype=float32),
#  array(2.7958515, dtype=float32),
#  array(2.4869533, dtype=float32),
#  array(2.3879201, dtype=float32),
#  array(2.5166383, dtype=float32),
#  array(2.4672089, dtype=float32),
#  array(2.9497075, dtype=float32),
#  array(2.7418659, dtype=float32),
#  array(2.1221952, dtype=float32),
#  array(2.8764288, dtype=float32),
#  array(2.989625, dtype=float32),
#  array(2.1268141, dtype=float32),
#  array(3.409614, dtype=float32),
#  array(3.499883, dtype=float32),
#  array(2.1882348, dtype=float32),
#  array(2.953514, dtype=float32),
#  array(2.795249, dtype=float32),
#  array(2.3303437, dtype=float32),
#  array(3.3679402, dtype=float32),
#  array(3.1627953, dtype=float32),
#  array(2.136037, dtype=float32),
#  array(2.8662872, dtype=float32),
#  array(2.5791745, dtype=float32),
#  array(2.2488952, dtype=float32),
#  array(2.7570443, dtype=float32),
#  array(1.8329693, dtype=float32),
#  array(2.4884408, dtype=float32),
#  array(2.885077, dtype=float32),
#  array(2.3173685, dtype=float32),
#  array(2.6042786, dtype=float32),
#  array(2.670334, dtype=float32),
#  array(2.1886842, dtype=float32),
#  array(2.8369453, dtype=float32),
#  array(2.3268032, dtype=float32),
#  array(2.3271713, dtype=float32),
#  array(2.1937423, dtype=float32),
#  array(2.2389026, dtype=float32),
#  array(2.2513874, dtype=float32),
#  array(2.137882, dtype=float32),
#  array(2.4137201, dtype=float32),
#  array(2.0898874, dtype=float32),
#  array(2.2721674, dtype=float32),
#  array(2.445153, dtype=float32),
#  array(2.2678988, dtype=float32),
#  array(2.1816273, dtype=float32),
#  array(2.7541795, dtype=float32),
#  array(2.159115, dtype=float32),
#  array(2.3530302, dtype=float32),
#  array(2.2988682, dtype=float32),
#  array(1.9974566, dtype=float32),
#  array(2.142924, dtype=float32),
#  array(2.1626544, dtype=float32),
#  array(1.9662488, dtype=float32),
#  array(2.1767938, dtype=float32),
#  array(2.455266, dtype=float32),
#  array(1.9078525, dtype=float32),
#  array(2.2699633, dtype=float32),
#  array(2.35667, dtype=float32),
#  array(2.188765, dtype=float32),
#  array(2.2910392, dtype=float32),
#  array(1.9905932, dtype=float32),
#  array(2.3985338, dtype=float32),
#  array(2.0373263, dtype=float32),
#  array(1.8390114, dtype=float32),
#  array(2.4938853, dtype=float32),
#  array(2.3639133, dtype=float32),
#  array(2.2267594, dtype=float32),
#  array(2.2327037, dtype=float32),
#  array(2.2556367, dtype=float32),
#  array(2.6373024, dtype=float32),
#  array(2.28252, dtype=float32),
#  array(2.191026, dtype=float32),
#  array(2.2328987, dtype=float32),
#  array(2.1247773, dtype=float32),
#  array(1.9651537, dtype=float32),
#  array(2.781153, dtype=float32),
#  array(2.0184598, dtype=float32),
#  array(1.9487283, dtype=float32),
#  array(2.3682413, dtype=float32),
#  array(2.1083326, dtype=float32),
#  array(2.2038338, dtype=float32),
#  array(3.0759883, dtype=float32),
#  array(3.2676835, dtype=float32),
#  array(2.213214, dtype=float32),
#  array(2.0011983, dtype=float32),
#  array(2.557565, dtype=float32),
#  array(2.60199, dtype=float32),
#  array(2.089129, dtype=float32),
#  array(2.1397073, dtype=float32),
#  array(2.1423724, dtype=float32),
#  array(1.983341, dtype=float32),
#  array(2.3732343, dtype=float32),
#  array(2.3830872, dtype=float32),
#  array(2.168408, dtype=float32),
#  array(2.521484, dtype=float32),
#  array(3.0527213, dtype=float32),
#  array(2.240636, dtype=float32),
#  array(1.84396, dtype=float32),
#  array(2.3524404, dtype=float32),
#  array(2.762021, dtype=float32),
#  array(1.9766235, dtype=float32),
#  array(2.316803, dtype=float32),
#  array(2.5468898, dtype=float32),
#  array(2.5068133, dtype=float32),
#  array(2.212024, dtype=float32),
#  array(1.8819115, dtype=float32),
#  array(2.0654683, dtype=float32),
#  array(1.929167, dtype=float32),
#  array(1.8845098, dtype=float32),
#  array(1.8117113, dtype=float32),
#  array(1.6997302, dtype=float32),
#  array(1.79989, dtype=float32),
#  array(1.9244803, dtype=float32),
#  array(2.13096, dtype=float32),
#  array(2.1015596, dtype=float32),
#  array(1.7321038, dtype=float32),
#  array(2.2071824, dtype=float32),
#  array(2.2690372, dtype=float32),
#  array(1.9851239, dtype=float32),
#  array(2.2227154, dtype=float32),
#  array(2.1768758, dtype=float32),
#  array(1.7461274, dtype=float32),
#  array(2.2661667, dtype=float32),
#  array(2.3609254, dtype=float32),
#  array(1.9093733, dtype=float32),
#  array(2.1355264, dtype=float32),
#  array(2.7192986, dtype=float32),
#  array(1.9470911, dtype=float32),
#  array(2.4086647, dtype=float32),
#  array(2.2792122, dtype=float32),
#  array(1.8284823, dtype=float32),
#  array(2.3844106, dtype=float32),
#  array(2.2797759, dtype=float32),
#  array(2.036353, dtype=float32),
#  array(1.4637035, dtype=float32),
#  array(1.8964678, dtype=float32),
#  array(1.9587055, dtype=float32),
#  array(2.3015995, dtype=float32),
#  array(1.7916911, dtype=float32),
#  array(1.9568102, dtype=float32),
#  array(1.8044915, dtype=float32),
#  array(2.1115904, dtype=float32),
#  array(1.7781291, dtype=float32),
#  array(2.0140917, dtype=float32),
#  array(1.9196447, dtype=float32),
#  array(2.2396955, dtype=float32),
#  array(2.0536535, dtype=float32),
#  array(1.7727089, dtype=float32),
#  array(2.2070944, dtype=float32),
#  array(2.0977666, dtype=float32),
#  array(1.8246021, dtype=float32),
#  array(2.2998595, dtype=float32),
#  array(2.1040497, dtype=float32),
#  array(1.5483686, dtype=float32),
#  array(2.256645, dtype=float32),
#  array(2.3117652, dtype=float32),
#  array(2.1817336, dtype=float32),
#  array(2.0741236, dtype=float32),
#  array(2.2923367, dtype=float32),
#  array(2.1410844, dtype=float32),
#  array(1.7646785, dtype=float32),
#  array(1.8830895, dtype=float32),
#  array(1.972518, dtype=float32),
#  array(1.7050331, dtype=float32),
#  array(1.9471179, dtype=float32),
#  array(2.012267, dtype=float32),
#  array(2.395637, dtype=float32),
#  array(1.7588154, dtype=float32),
#  array(1.9095268, dtype=float32),
#  array(1.7809725, dtype=float32),
#  array(1.9140457, dtype=float32),
#  array(1.6762218, dtype=float32),
#  array(1.6694143, dtype=float32),
#  array(1.7694044, dtype=float32),
#  array(1.8908654, dtype=float32),
#  array(1.465501, dtype=float32),
#  array(1.5979259, dtype=float32),
#  array(2.0150661, dtype=float32),
#  array(1.8603212, dtype=float32),
#  array(2.2032723, dtype=float32),
#  array(1.9051757, dtype=float32),
#  array(1.8868771, dtype=float32),
#  array(2.06633, dtype=float32),
#  array(2.046715, dtype=float32),
#  array(1.7797084, dtype=float32),
#  array(1.7195584, dtype=float32),
#  array(1.6500982, dtype=float32),
#  array(1.4994905, dtype=float32),
#  array(2.1723006, dtype=float32),
#  array(1.9064513, dtype=float32),
#  array(1.7838192, dtype=float32),
#  array(1.7467993, dtype=float32),
#  array(1.6802906, dtype=float32),
#  array(1.7969131, dtype=float32),
#  array(1.870239, dtype=float32),
#  array(1.6207153, dtype=float32),
#  array(1.6345412, dtype=float32),
#  array(1.9794419, dtype=float32),
#  array(2.0486462, dtype=float32),
#  array(2.1928911, dtype=float32),
#  array(1.6629055, dtype=float32),
#  array(2.197672, dtype=float32),
#  array(2.72421, dtype=float32),
#  array(2.5831807, dtype=float32),
#  array(1.6880475, dtype=float32),
#  array(2.167335, dtype=float32),
#  array(2.6137035, dtype=float32),
#  array(2.3097317, dtype=float32),
#  array(1.7181842, dtype=float32),
#  array(2.3200583, dtype=float32),
#  array(2.4406495, dtype=float32),
#  array(1.940784, dtype=float32),
#  array(1.7221689, dtype=float32),
#  array(1.9017988, dtype=float32),
#  array(2.2003558, dtype=float32),
#  array(1.7003658, dtype=float32),
#  array(1.6287303, dtype=float32),
#  array(1.9795156, dtype=float32),
#  array(2.0029817, dtype=float32),
#  array(1.8053228, dtype=float32),
#  array(2.132888, dtype=float32),
#  array(2.1754663, dtype=float32),
#  array(2.4812164, dtype=float32),
#  array(1.834842, dtype=float32),
#  array(1.43087, dtype=float32),
#  array(1.9047596, dtype=float32),
#  array(2.3956606, dtype=float32),
#  array(2.4081306, dtype=float32),
#  array(2.0481148, dtype=float32),
#  array(1.6897118, dtype=float32),
#  array(2.048112, dtype=float32),
#  array(2.0952492, dtype=float32),
#  array(1.7434137, dtype=float32),
#  array(1.6081724, dtype=float32),
#  array(1.7486765, dtype=float32),
#  array(1.8278759, dtype=float32),
#  array(1.6382853, dtype=float32),
#  array(1.7024918, dtype=float32),
#  array(1.4397416, dtype=float32),
#  array(1.7639004, dtype=float32),
#  array(1.631394, dtype=float32),
#  array(1.6530902, dtype=float32),
#  array(1.9902003, dtype=float32),
#  array(1.8115897, dtype=float32),
#  array(1.8156, dtype=float32),
#  array(1.6795207, dtype=float32),
#  array(1.6340504, dtype=float32),
#  array(1.6719401, dtype=float32),
#  array(1.6876163, dtype=float32),
#  array(1.7508347, dtype=float32),
#  array(1.3511143, dtype=float32),
#  array(1.5861244, dtype=float32),
#  array(1.5981723, dtype=float32),
#  array(1.7197518, dtype=float32),
#  array(2.040217, dtype=float32),
#  array(1.7240391, dtype=float32),
#  array(1.8843844, dtype=float32),
#  array(1.5752107, dtype=float32),
#  array(1.6214149, dtype=float32),
#  array(1.8972386, dtype=float32),
#  array(1.4165115, dtype=float32),
#  array(1.743744, dtype=float32),
#  array(1.7288276, dtype=float32),
#  array(1.408091, dtype=float32),
#  array(1.5914861, dtype=float32),
#  array(1.5021819, dtype=float32),
#  array(2.0625708, dtype=float32),
#  array(1.7469764, dtype=float32),
#  array(1.7256266, dtype=float32),
#  array(1.9497286, dtype=float32),
#  array(1.61326, dtype=float32),
#  array(1.7204281, dtype=float32),
#  array(1.8670883, dtype=float32),
#  array(1.378797, dtype=float32),
#  array(1.7523105, dtype=float32),
#  array(1.6006871, dtype=float32),
#  array(2.1046445, dtype=float32),
#  array(1.8224995, dtype=float32),
#  array(1.5629654, dtype=float32),
#  array(2.2816744, dtype=float32),
#  array(2.6747732, dtype=float32),
#  array(2.0131752, dtype=float32),
#  array(1.6415915, dtype=float32),
#  array(2.1854637, dtype=float32),
#  array(2.831862, dtype=float32),
#  array(2.4029248, dtype=float32),
#  array(1.7024813, dtype=float32),
#  array(1.7523986, dtype=float32),
#  array(2.4369822, dtype=float32),
#  array(2.0697286, dtype=float32),
#  array(1.6433963, dtype=float32),
#  array(2.1930006, dtype=float32),
#  array(3.0537834, dtype=float32),
#  array(2.8016706, dtype=float32),
#  array(2.2208266, dtype=float32),
#  array(1.7029217, dtype=float32),
#  array(1.7056379, dtype=float32),
#  array(1.9502594, dtype=float32),
#  array(1.7434903, dtype=float32),
#  array(2.014213, dtype=float32),
#  array(2.0909986, dtype=float32),
#  array(1.8676783, dtype=float32),
#  array(2.0519743, dtype=float32),
#  array(1.5458046, dtype=float32),
#  array(1.7218019, dtype=float32),
#  array(2.117453, dtype=float32),
#  array(1.7631121, dtype=float32),
#  array(1.4573857, dtype=float32),
#  array(1.9114169, dtype=float32),
#  array(2.0741787, dtype=float32),
#  array(1.7075077, dtype=float32),
#  array(1.5337989, dtype=float32),
#  array(1.665482, dtype=float32),
#  array(2.014129, dtype=float32),
#  array(2.1119199, dtype=float32),
#  array(1.6323551, dtype=float32),
#  array(1.6713616, dtype=float32),
#  array(1.8209468, dtype=float32),
#  array(2.0606215, dtype=float32),
#  array(1.4916124, dtype=float32),
#  array(1.6783307, dtype=float32),
#  array(1.8045973, dtype=float32),
#  array(1.5590444, dtype=float32),
#  array(1.4719613, dtype=float32),
#  array(1.8016729, dtype=float32),
#  array(1.5383312, dtype=float32),
#  array(1.486957, dtype=float32),
#  array(1.5284631, dtype=float32),
#  array(1.6671994, dtype=float32),
#  array(1.452659, dtype=float32),
#  array(1.5049642, dtype=float32),
#  array(1.37695, dtype=float32),
#  array(1.4119681, dtype=float32),
#  array(1.7192394, dtype=float32),
#  array(1.6095634, dtype=float32),
#  array(1.3763083, dtype=float32),
#  array(1.3470383, dtype=float32),
#  array(1.5576624, dtype=float32),
#  array(1.6645668, dtype=float32),
#  array(1.300674, dtype=float32),
#  array(1.756028, dtype=float32),
#  array(1.6933584, dtype=float32),
#  array(1.8769811, dtype=float32),
#  array(1.6178699, dtype=float32),
#  array(1.3946851, dtype=float32),
#  array(2.1613004, dtype=float32),
#  array(1.7524326, dtype=float32),
#  array(1.569849, dtype=float32),
#  array(1.6984605, dtype=float32),
#  array(1.7805729, dtype=float32),
#  array(2.0688846, dtype=float32),
#  array(2.1458547, dtype=float32),
#  array(1.6144477, dtype=float32),
#  array(1.5614903, dtype=float32),
#  array(1.9151759, dtype=float32),
#  array(1.9638665, dtype=float32),
#  array(2.1148312, dtype=float32),
#  array(1.7863206, dtype=float32),
#  array(1.7239966, dtype=float32),
#  array(1.6775635, dtype=float32),
#  array(2.0274494, dtype=float32),
#  array(1.6373742, dtype=float32),
#  array(1.6016029, dtype=float32),
#  array(1.5645559, dtype=float32),
#  array(1.6299412, dtype=float32),
#  array(1.4566524, dtype=float32),
#  array(1.5374587, dtype=float32),
#  array(1.5550255, dtype=float32),
#  array(1.5030845, dtype=float32),
#  array(1.7823972, dtype=float32),
#  array(1.7932513, dtype=float32),
#  array(1.8821793, dtype=float32),
#  array(1.3237206, dtype=float32),
#  array(1.554899, dtype=float32),
#  array(1.9431176, dtype=float32),
#  array(2.0040188, dtype=float32),
#  array(2.0210903, dtype=float32),
#  array(1.8087683, dtype=float32),
#  array(1.5763856, dtype=float32),
#  array(1.7129945, dtype=float32),
#  array(1.9100133, dtype=float32),
#  array(2.184657, dtype=float32),
#  array(1.6517177, dtype=float32),
#  array(1.7012964, dtype=float32),
#  array(1.557761, dtype=float32),
#  array(2.1252573, dtype=float32),
#  array(1.6291419, dtype=float32),
#  array(1.7778541, dtype=float32),
#  array(1.475133, dtype=float32),
#  array(1.611128, dtype=float32),
#  array(1.46137, dtype=float32),
#  array(1.502699, dtype=float32),
#  array(1.3945894, dtype=float32),
#  array(1.2463921, dtype=float32),
#  array(1.7599173, dtype=float32),
#  array(2.4472175, dtype=float32),
#  array(2.0529997, dtype=float32),
#  array(1.572715, dtype=float32),
#  array(2.0757966, dtype=float32),
#  array(2.9829357, dtype=float32),
#  array(3.2473497, dtype=float32),
#  array(2.030381, dtype=float32),
#  array(1.4518201, dtype=float32),
#  array(2.167972, dtype=float32),
#  array(3.3132226, dtype=float32),
#  array(3.2315784, dtype=float32),
#  array(1.91995, dtype=float32),
#  array(1.616075, dtype=float32),
#  array(2.3535316, dtype=float32),
#  array(2.4184968, dtype=float32),
#  array(1.6827426, dtype=float32),
#  array(2.1630282, dtype=float32),
#  array(3.8550704, dtype=float32),
#  array(3.09573, dtype=float32),
#  array(1.6887662, dtype=float32),
#  array(1.5411699, dtype=float32),
#  array(2.3860607, dtype=float32),
#  array(2.0807643, dtype=float32),
#  array(1.5043445, dtype=float32),
#  array(1.7779312, dtype=float32),
#  array(1.8776537, dtype=float32),
#  array(1.6696551, dtype=float32),
#  array(1.7524929, dtype=float32),
#  array(2.2187824, dtype=float32),
#  array(1.7901971, dtype=float32),
#  array(1.421764, dtype=float32),
#  array(1.9866128, dtype=float32),
#  array(2.1725335, dtype=float32),
#  array(2.0927522, dtype=float32),
#  array(1.557801, dtype=float32),
#  array(1.5436294, dtype=float32),
#  array(1.8348147, dtype=float32),
#  array(2.0289493, dtype=float32),
#  array(1.7217369, dtype=float32),
#  array(1.7106951, dtype=float32),
#  array(2.2031326, dtype=float32),
#  array(2.0866392, dtype=float32),
#  array(1.6953092, dtype=float32),
#  array(1.1883814, dtype=float32),
#  array(1.7240409, dtype=float32),
#  array(2.506567, dtype=float32),
#  array(2.351611, dtype=float32),
#  array(1.4690564, dtype=float32),
#  array(2.4441285, dtype=float32),
#  array(2.7600875, dtype=float32),
#  array(1.9039865, dtype=float32),
#  array(1.5407047, dtype=float32),
#  ...]

# %%
# evaulate
trainer.evaluate(test_data)
# Out:
# 1.030415

# %% [markdown]
# Since the total loss is a low 1.030415, we can see that this is a very good prediction.
